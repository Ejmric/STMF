# %%
import sys
sys.path.append("..")
from utils import plot_dataset, plot_statistics

# %% [markdown]
# # 1. GBM

# %% [markdown]
# ### Methylation data

# %%
original_path  = "../multi_omic/GBM/methy.txt"
transformed_path = "../multi_omic/GBM/GBM_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# The number of columns in transformed subset is less than in original data because we analyze only a subset of original columns (patients) for which exist data for all three sets: gene expression, methylation, and miRNA.

# %% [markdown]
# ### Gene expression data

# %%
original_path  = "../multi_omic/GBM/exp.txt"
transformed_path = "../multi_omic/GBM/GBM_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path  = "../multi_omic/GBM/mirna.txt"              
transformed_path = "../multi_omic/GBM/GBM_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 2. 0V

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/OV/methy.txt"
transformed_path = "../multi_omic/OV/OV_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path = "../multi_omic/OV/exp.txt"
transformed_path = "../multi_omic/OV/OV_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/OV/mirna.txt"
transformed_path = "../multi_omic/OV/OV_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 3. AML

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/AML/methy.txt"
transformed_path = "../multi_omic/AML/AML_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path = "../multi_omic/AML/exp.txt"
transformed_path = "../multi_omic/AML/AML_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/AML/mirna.txt"
transformed_path = "../multi_omic/AML/AML_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 4. BIC

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/BIC/methy.txt"
transformed_path = "../multi_omic/BIC/BIC_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path  = "../multi_omic/BIC/exp.txt"
transformed_path = "../multi_omic/BIC/BIC_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/BIC/mirna.txt"
transformed_path = "../multi_omic/BIC/BIC_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 5. COLON

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/COLON/methy.txt"
transformed_path = "../multi_omic/COLON/COLON_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path = "../multi_omic/COLON/exp.txt"
transformed_path = "../multi_omic/COLON/COLON_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/COLON/mirna.txt" 
transformed_path = "../multi_omic/COLON/COLON_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 6. KIDNEY (only one with negative values)

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/Kidney/methy.txt"
transformed_path = "../multi_omic/Kidney/Kidney_methylation_subset.txt"
plot_dataset(original_path, transformed_path)
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:746: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:747: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path = "../multi_omic/Kidney/exp.txt"
transformed_path = "../multi_omic/Kidney/Kidney_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/Kidney/mirna.txt"
transformed_path = "../multi_omic/Kidney/Kidney_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 7. LIHC

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/LIHC/methy.txt"
transformed_path = "../multi_omic/LIHC/LIHC_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path = "../multi_omic/LIHC/exp.txt"
transformed_path = "../multi_omic/LIHC/LIHC_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/LIHC/mirna.txt"
transformed_path = "../multi_omic/LIHC/LIHC_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 8. LUSC

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/LUSC/methy.txt"
transformed_path = "../multi_omic/LUSC/LUSC_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path = "../multi_omic/LUSC/exp.txt"
transformed_path = "../multi_omic/LUSC/LUSC_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/LUSC/mirna.txt"
transformed_path = "../multi_omic/LUSC/LUSC_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 9. SARC

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/SARC/methy.txt"
transformed_path = "../multi_omic/SARC/SARC_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path = "../multi_omic/SARC/exp.txt"
transformed_path = "../multi_omic/SARC/SARC_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/SARC/mirna.txt"
transformed_path = "../multi_omic/SARC/SARC_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# # 10. SKCM

# %% [markdown]
# ### Methylation data

# %%
original_path = "../multi_omic/SKCM/methy.txt"
transformed_path = "../multi_omic/SKCM/SKCM_methylation_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### Gene expression data

# %%
original_path = "../multi_omic/SKCM/exp.txt"
transformed_path =  "../multi_omic/SKCM/SKCM_gene_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)

# %% [markdown]
# ### miRNA data

# %%
original_path = "../multi_omic/SKCM/mirna.txt"
transformed_path = "../multi_omic/SKCM/SKCM_mirna_subset.txt"
plot_dataset(original_path, transformed_path)

# %%
plot_statistics(original_path, transformed_path)
